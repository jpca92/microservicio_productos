# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Matriz_final_1.csv', sep="|", dtype=str).fillna("")
df.to_parquet(
    'datos_endpoint.parquet',
    engine= 'pyarrow',
    compression= 'snappy',
    index= False
)

# %%
df
# Out:
#      Referencia_del_producto  \
# 0       MA04TKI001-22200-N01
# 1       MA04COM071-24260-000
# 2       AC52TLB002-1610Z-XXX
# 3       AC59IND427-2020Z-G17
# 4       AC59IND427-2020Z-G13
# ...                      ...
# 2379       RA44429-2521-B72M
# 2380       RA44429-2522-N01M
# 2381       RA44429-2522-N01L
# 2382       RA21475-2520-M5QM
# 2383       RA21475-2520-N01M
#
#                                         Nombre_producto  \
# 0     Morral Universitario Porta PC 14" Trik Mediano...
# 1     Combo Escolar Morral Acuarela, Lonchera Pizarr...
# 2                       Cartuchera Personalizable Teken
# 3                                    Llavero Tapak Gris
# 4                                    Llavero Tapak Gris
# ...                                                 ...
# 2379                Buzo Para Hombre Shabaout Terreo M
# 2380                 Buzo Para Hombre Shabaout Negro M
# 2381                 Buzo Para Hombre Shabaout Negro L
# ...
